# %%
import pandas as pd
import numpy as np
import pickle  # Using pickle for binary storage
import os
import argparse
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# File to store learned data (from user feedback) in binary format
learned_data_file = "gender_learnings_phonetic.pkl"
model_file = "gender_model.pkl"

# Load learned data from the pickle file
def load_learnings():
    if os.path.exists(learned_data_file):
        print(f"[DEBUG] Loading learnings from {learned_data_file}...")  # Step 1
        with open(learned_data_file, "rb") as file:
            learnings = pickle.load(file)
            print(f"[DEBUG] Loaded learnings: {learnings}")  # Step 2
            return learnings
    print(f"[DEBUG] No learned data found. Starting fresh.")  # Step 3
    return {}

# Save learned data to the pickle file
def save_learnings(learnings):
    print(f"[DEBUG] Saving learnings to {learned_data_file}...")  # Step 4
    with open(learned_data_file, "wb") as file:
        pickle.dump(learnings, file)
    print(f"[DEBUG] Learnings saved.")  # Step 5

# Load name-gender dataset from CSV
def load_dataset(filename):
    print(f"[DEBUG] Loading dataset from {filename}...")  # Step 6
    df = pd.read_csv(filename)
    print(f"[DEBUG] Dataset loaded with {len(df)} records.")  # Step 7
    return df[['name', 'gender', 'probability']]

# Train a gender prediction model using a dataset of names
def train_model(df):
    print("[DEBUG] Starting model training...")  # Step 8
    vectorizer = CountVectorizer(analyzer='char', ngram_range=(2, 3))  # Use character bigrams and trigrams
    print("[DEBUG] Vectorizing names...")  # Step 9
    X = vectorizer.fit_transform(df['name'])
    
    le = LabelEncoder()
    print("[DEBUG] Encoding gender labels...")  # Step 10
    y = le.fit_transform(df['gender'])

    # Get probability values as weights
    sample_weights = df['probability'].values
    print(f"[DEBUG] Sample weights: {sample_weights}")  # Step 11

    # Train-test split
    print("[DEBUG] Splitting data into training and testing sets...")  # Step 12
    X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(X, y, sample_weights, test_size=0.2, random_state=42)

    print("[DEBUG] Training logistic regression model...")  # Step 13
    model = LogisticRegression()
    model.fit(X_train, y_train, sample_weight=w_train)

    # Evaluate the model
    print("[DEBUG] Evaluating model performance...")  # Step 14
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"[DEBUG] Model accuracy: {accuracy:.2f}")  # Step 15

    # Save the trained model
    save_model(model, vectorizer, le)

    return model, vectorizer, le

# Save the model to a pickle file
def save_model(model, vectorizer, le):
    print(f"[DEBUG] Saving trained model to {model_file}...")  # Step 16
    with open(model_file, "wb") as f:
        pickle.dump((model, vectorizer, le), f)
    print(f"[DEBUG] Model saved to {model_file}.")  # Step 17

# Load the model from the pickle file
def load_model():
    if os.path.exists(model_file):
        print(f"[DEBUG] Loading trained model from {model_file}...")  # Step 18
        with open(model_file, "rb") as f:
            model, vectorizer, le = pickle.load(f)
            print("[DEBUG] Model loaded successfully.")  # Step 19
            return model, vectorizer, le
    print(f"[DEBUG] No model found. Please train the model first.")  # Step 20
    return None, None, None

# Predict gender based on the name using the trained model
def predict_gender_ml(name, model, vectorizer, le, learnings):
    name_lower = name.lower()
    
    # Check if the name exists in the learned data first
    if name_lower in learnings:
        print(f"[DEBUG] Found '{name}' in learnings. Using learned gender: {learnings[name_lower]}")  # Step 21
        return learnings[name_lower]
    
    # If not found in learnings, use the ML model to predict
    print(f"[DEBUG] '{name}' not found in learnings. Using ML model for prediction...")  # Step 22
    name_features = vectorizer.transform([name])
    predicted_gender_idx = model.predict(name_features)[0]
    predicted_gender = le.inverse_transform([predicted_gender_idx])[0]
    
    print(f"[DEBUG] ML model prediction for '{name}': {predicted_gender}")  # Step 23
    return predicted_gender

# Main function to handle training and predictions
def main():
    parser = argparse.ArgumentParser(description="Train or predict gender based on name.")
    parser.add_argument('csvfile', nargs='?', help="Path to the CSV file containing name, gender, and probability columns (optional).")
    parser.add_argument('action', nargs='?', choices=['train', 'predict'], help="Action to perform: 'train' or 'predict'.")
    args = parser.parse_args()

    # Load learned data
    learnings = load_learnings()

    if args.csvfile and args.action == 'train':
        df = load_dataset(args.csvfile)
        model, vectorizer, le = train_model(df)
        print("[DEBUG] Model training completed. Ready for prediction.")
    else:
        model, vectorizer, le = load_model()
        if model is None:
            return

    # Continuous name prediction loop
    while True:
        name = input("Enter a name (or type 'exit' to quit): ").strip()
        if name.lower() == 'exit':
            break

        predicted_gender = predict_gender_ml(name, model, vectorizer, le, learnings)
        print(f"The predicted gender for '{name}' is: {predicted_gender}")

        correct = input(f"Is this correct? (yes/no): ").strip().lower()
        if correct == 'no':
            actual_gender = input("Please provide the correct gender (male/female): ").strip().lower()

            # Save this learning for future predictions
            learnings[name.lower()] = actual_gender
            save_learnings(learnings)
            print(f"[DEBUG] Learning saved: '{name}' is {actual_gender}.")

        continue_predicting = input("Do you want to enter another name? (yes/no): ").strip().lower()
        if continue_predicting == 'no':
            break

if __name__ == "__main__":
    main()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 555, in drive
#     return self._drv
#            ^^^^^^^^^
# AttributeError: 'WindowsPath' object has no attribute '_drv'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2972, in safe_execfile_ipy
#     fname = Path(fname).expanduser().resolve()
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 1402, in expanduser
#     if (not (self.drive or self.root) and
#              ^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 557, in drive
#     self._load_parts()
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 415, in _load_parts
#     drv, root, tail = self._parse_path(path)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 395, in _parse_path
#     drv, root, rel = cls._flavour.splitroot(path)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1083, in format_exception_as_a_whole
#     head = self.prepare_header(str(etype), self.long_header)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1001, in prepare_header
#     width = min(75, get_terminal_size()[0])
#                     ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\utils\terminal.py", line 131, in get_terminal_size
#     return _get_terminal_size((defaultx, defaulty))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\shutil.py", line 1443, in get_terminal_size
#     columns = int(os.environ['COLUMNS'])
#                   ~~~~~~~~~~^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3599, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 180, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1083, in format_exception_as_a_whole
#     head = self.prepare_header(str(etype), self.long_header)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1001, in prepare_header
#     width = min(75, get_terminal_size()[0])
#                     ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\utils\terminal.py", line 131, in get_terminal_size
#     return _get_terminal_size((defaultx, defaulty))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\shutil.py", line 1443, in get_terminal_size
#     columns = int(os.environ['COLUMNS'])
#                   ~~~~~~~~~~^^^^^^^^^^^
#   File "<frozen os>", line 711, in __getitem__
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              ^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3536, in run_ast_nodes
#     self.showtraceback()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 180, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 138, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1085, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1182, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "D:\System_Installs\Development\python\Lib\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "D:\System_Installs\Development\python\Lib\site-packages\stack_data\core.py", line 587, in mapper
#     return cls(f, options)
#            ^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\stack_data\core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 264, in executing
#     source = cls.for_frame(frame)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 183, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 203, in for_filename
#     lines = get_lines()
#             ^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 198, in get_lines
#     return linecache.getlines(cast(str, filename), module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 138, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\tokenize.py", line 451, in open
#     encoding, lines = detect_encoding(buffer.readline)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\tokenize.py", line 428, in detect_encoding
#     encoding = find_cookie(first)
#                ^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\tokenize.py", line 397, in find_cookie
#     encoding = _get_normal_name(match.group(1))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 555, in drive
#     return self._drv
#            ^^^^^^^^^
# AttributeError: 'WindowsPath' object has no attribute '_drv'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2972, in safe_execfile_ipy
#     fname = Path(fname).expanduser().resolve()
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 1402, in expanduser
#     if (not (self.drive or self.root) and
#              ^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 557, in drive
#     self._load_parts()
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 415, in _load_parts
#     drv, root, tail = self._parse_path(path)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 395, in _parse_path
#     drv, root, rel = cls._flavour.splitroot(path)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1083, in format_exception_as_a_whole
#     head = self.prepare_header(str(etype), self.long_header)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1001, in prepare_header
#     width = min(75, get_terminal_size()[0])
#                     ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\utils\terminal.py", line 131, in get_terminal_size
#     return _get_terminal_size((defaultx, defaulty))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\shutil.py", line 1443, in get_terminal_size
#     columns = int(os.environ['COLUMNS'])
#                   ~~~~~~~~~~^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3599, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 180, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1083, in format_exception_as_a_whole
#     head = self.prepare_header(str(etype), self.long_header)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1001, in prepare_header
#     width = min(75, get_terminal_size()[0])
#                     ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\utils\terminal.py", line 131, in get_terminal_size
#     return _get_terminal_size((defaultx, defaulty))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\shutil.py", line 1443, in get_terminal_size
#     columns = int(os.environ['COLUMNS'])
#                   ~~~~~~~~~~^^^^^^^^^^^
#   File "<frozen os>", line 711, in __getitem__
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              ^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3536, in run_ast_nodes
#     self.showtraceback()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 180, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 138, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1085, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1182, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "D:\System_Installs\Development\python\Lib\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "D:\System_Installs\Development\python\Lib\site-packages\stack_data\core.py", line 587, in mapper
#     return cls(f, options)
#            ^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\stack_data\core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 264, in executing
#     source = cls.for_frame(frame)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 183, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 212, in for_filename
#     return cls._for_filename_and_lines(filename, tuple(lines))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 223, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#                                                ^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 174, in __init__
#     visitor.visit(self.tree)
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 407, in visit
#     return visitor(node)
#            ^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 415, in generic_visit
#     self.visit(item)
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 407, in visit
#     return visitor(node)
#            ^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 415, in generic_visit
#     self.visit(item)
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 407, in visit
#     return visitor(node)
#            ^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 415, in generic_visit
#     self.visit(item)
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 407, in visit
#     return visitor(node)
#            ^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\executing\executing.py", line 492, in visit_ClassDef
#     self.generic_visit(node)
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 415, in generic_visit
#     self.visit(item)
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 407, in visit
#     return visitor(node)
#            ^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 415, in generic_visit
#     self.visit(item)
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 407, in visit
#     return visitor(node)
#            ^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 417, in generic_visit
#     self.visit(value)
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 407, in visit
#     return visitor(node)
#            ^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\ast.py", line 411, in generic_visit
#     for field, value in iter_fields(node):
#                         ^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 555, in drive
#     return self._drv
#            ^^^^^^^^^
# AttributeError: 'WindowsPath' object has no attribute '_drv'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2972, in safe_execfile_ipy
#     fname = Path(fname).expanduser().resolve()
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 1402, in expanduser
#     if (not (self.drive or self.root) and
#              ^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 557, in drive
#     self._load_parts()
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 415, in _load_parts
#     drv, root, tail = self._parse_path(path)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\pathlib.py", line 395, in _parse_path
#     drv, root, rel = cls._flavour.splitroot(path)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1083, in format_exception_as_a_whole
#     head = self.prepare_header(str(etype), self.long_header)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1001, in prepare_header
#     width = min(75, get_terminal_size()[0])
#                     ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\utils\terminal.py", line 131, in get_terminal_size
#     return _get_terminal_size((defaultx, defaulty))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\shutil.py", line 1443, in get_terminal_size
#     columns = int(os.environ['COLUMNS'])
#                   ~~~~~~~~~~^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3599, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 180, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1083, in format_exception_as_a_whole
#     head = self.prepare_header(str(etype), self.long_header)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1001, in prepare_header
#     width = min(75, get_terminal_size()[0])
#                     ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\utils\terminal.py", line 131, in get_terminal_size
#     return _get_terminal_size((defaultx, defaulty))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\shutil.py", line 1443, in get_terminal_size
#     columns = int(os.environ['COLUMNS'])
#                   ~~~~~~~~~~^^^^^^^^^^^
#   File "<frozen os>", line 711, in __getitem__
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HimakarRaju\AppData\Local\Temp\ipykernel_14596\592218724.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'sircode.ipynb')
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              ^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 3536, in run_ast_nodes
#     self.showtraceback()
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 180, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "D:\System_Installs\Development\python\Lib\traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\linecache.py", line 138, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py", line 1457, in structured_traceback
# ...
#     731 self.max_group_depth = max_group_depth
# --> 733 self.stack = StackSummary._extract_from_extended_frame_gen(
#     734     _walk_tb_with_full_positions(exc_traceback),
#     735     limit=limit, lookup_lines=lookup_lines,
#     736     capture_locals=capture_locals)
#     737 self.exc_type = exc_type
#
# File D:\System_Installs\Development\python\Lib\traceback.py:438, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     437     for f in result:
# --> 438         f.line
#     439 return result
#
# File D:\System_Installs\Development\python\Lib\traceback.py:323, in FrameSummary.line(self)
#     322         return None
# --> 323     self._line = linecache.getline(self.filename, self.lineno)
#     324 return self._line.strip()
#
# File D:\System_Installs\Development\python\Lib\linecache.py:30, in getline(filename, lineno, module_globals)
#      27 """Get a line for a Python source file from the cache.
#      28 Update the cache if it doesn't contain an entry for this file already."""
# ---> 30 lines = getlines(filename, module_globals)
#      31 if 1 <= lineno <= len(lines):
#
# File D:\System_Installs\Development\python\Lib\linecache.py:46, in getlines(filename, module_globals)
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:2168, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2167     else:
# -> 2168         stb = self.InteractiveTB.structured_traceback(
#    2169             etype, value, tb, tb_offset=tb_offset
#    2170         )
#    2172 except Exception:
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py:1457, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1456     self.tb = etb
# -> 1457 return FormattedTB.structured_traceback(
#    1458     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1459 )
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py:1348, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1346 if mode in self.verbose_modes:
#    1347     # Verbose modes need a full traceback
# -> 1348     return VerboseTB.structured_traceback(
#    1349         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1350     )
#    1351 elif mode == 'Minimal':
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py:1195, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1194 """Return a nice text document describing the traceback."""
# -> 1195 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1196                                                        tb_offset)
#    1198 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py:1083, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1082 assert isinstance(tb_offset, int)
# -> 1083 head = self.prepare_header(str(etype), self.long_header)
#    1084 records = (
#    1085     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1086 )
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\ultratb.py:1001, in VerboseTB.prepare_header(self, etype, long_version)
#    1000 exc = '%s%s%s' % (colors.excName, etype, colorsnormal)
# -> 1001 width = min(75, get_terminal_size()[0])
#    1002 if long_version:
#    1003     # Header with the exception type, python version, and date
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\utils\terminal.py:131, in get_terminal_size(defaultx, defaulty)
#     130 def get_terminal_size(defaultx=80, defaulty=25):
# --> 131     return _get_terminal_size((defaultx, defaulty))
#
# File D:\System_Installs\Development\python\Lib\shutil.py:1443, in get_terminal_size(fallback)
#    1442 try:
# -> 1443     columns = int(os.environ['COLUMNS'])
#    1444 except (KeyError, ValueError):
#
# File <frozen os>:711, in __getitem__(self, key)
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_line_magic('run', 'sircode.ipynb')
#       2 import pandas as pd
#       3 import numpy as np
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# Cell In[9], line 1
# ----> 1 get_ipython().run_line_magic('run', 'sircode.ipynb')
#       2 import pandas as pd
#       3 import numpy as np
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping similar frames: <module> at line 1 (56 times), ExecutionResult.raise_error at line 308 (56 times), ExecutionMagics.run at line 737 (56 times), InteractiveShell.run_code at line 3577 (56 times), InteractiveShell.run_line_magic at line 2480 (56 times), InteractiveShell.safe_execfile_ipy at line 3005 (56 times)]
#
#     [... skipping hidden 1 frame]
#
# Cell In[9], line 1
# ----> 1 get_ipython().run_line_magic('run', 'sircode.ipynb')
#       2 import pandas as pd
#       3 import numpy as np
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:3130, in InteractiveShell._run_cell(self, raw_cell, store_history, silent, shell_futures, cell_id)
#    3127     runner = _pseudo_sync_runner
#    3129 try:
# -> 3130     result = runner(coro)
#    3131 except BaseException as e:
#    3132     info = ExecutionInfo(
#    3133         raw_cell, store_history, silent, shell_futures, cell_id
#    3134     )
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)
#     125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:3334, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3330 # Execute the user code
#    3331 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3334 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3335        interactivity=interactivity, compiler=compiler, result=result)
#    3337 self.last_execution_succeeded = not has_raised
#    3338 self.last_execution_result = result
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:3536, in InteractiveShell.run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3534     if result:
#    3535         result.error_before_exec = sys.exc_info()[1]
# -> 3536     self.showtraceback()
#    3537     return True
#    3539 return False
#
# File D:\System_Installs\Development\python\Lib\site-packages\IPython\core\interactiveshell.py:2176, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2172 except Exception:
#    2173     print(
#    2174         "Unexpected exception formatting exception. Falling back to standard exception"
#    2175     )
# -> 2176     traceback.print_exc()
#    2177     return None
#    2179 self._showtraceback(etype, value, stb)
#
# File D:\System_Installs\Development\python\Lib\traceback.py:180, in print_exc(limit, file, chain)
#     178 def print_exc(limit=None, file=None, chain=True):
#     179     """Shorthand for 'print_exception(sys.exception(), limit, file, chain)'."""
# --> 180     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#
# File D:\System_Installs\Development\python\Lib\traceback.py:124, in print_exception(exc, value, tb, limit, file, chain)
#     113 """Print exception up to 'limit' stack trace entries from 'tb' to 'file'.
#     114
#     115 This differs from print_tb() in the following ways: (1) if
#    (...)
#     121 position of the error.
#     122 """
#     123 value, tb = _parse_value_tb(exc, value, tb)
# --> 124 te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#     125 te.print(file=file, chain=chain)
#
# File D:\System_Installs\Development\python\Lib\traceback.py:733, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     730 self.max_group_width = max_group_width
#     731 self.max_group_depth = max_group_depth
# --> 733 self.stack = StackSummary._extract_from_extended_frame_gen(
#     734     _walk_tb_with_full_positions(exc_traceback),
#     735     limit=limit, lookup_lines=lookup_lines,
#     736     capture_locals=capture_locals)
#     737 self.exc_type = exc_type
#     738 # Capture now to permit freeing resources: only complication is in the
#     739 # unofficial API _format_final_exc_line
#
# File D:\System_Installs\Development\python\Lib\traceback.py:438, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     436 if lookup_lines:
#     437     for f in result:
# --> 438         f.line
#     439 return result
#
# File D:\System_Installs\Development\python\Lib\traceback.py:323, in FrameSummary.line(self)
#     321     if self.lineno is None:
#     322         return None
# --> 323     self._line = linecache.getline(self.filename, self.lineno)
#     324 return self._line.strip()
#
# File D:\System_Installs\Development\python\Lib\linecache.py:30, in getline(filename, lineno, module_globals)
#      26 def getline(filename, lineno, module_globals=None):
#      27     """Get a line for a Python source file from the cache.
#      28     Update the cache if it doesn't contain an entry for this file already."""
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# File D:\System_Installs\Development\python\Lib\linecache.py:46, in getlines(filename, module_globals)
#      43         return cache[filename][2]
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#      48     clearcache()
#
# File D:\System_Installs\Development\python\Lib\linecache.py:138, in updatecache(filename, module_globals)
#     136     return []
#     137 try:
# --> 138     with tokenize.open(fullname) as fp:
#     139         lines = fp.readlines()
#     140 except (OSError, UnicodeDecodeError, SyntaxError):
#
# RecursionError: maximum recursion depth exceeded
